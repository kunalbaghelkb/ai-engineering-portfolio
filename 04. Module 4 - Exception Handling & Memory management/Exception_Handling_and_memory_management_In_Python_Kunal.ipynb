# %% [markdown]
# ### 1. What is Object-Oriented Programming (OOP)?
# OOP is a programming approach based on objects that contain data and methods.

# %% [markdown]
# ### 2. What is a class in OOP?
# A class is a blueprint for creating objects.

# %% [markdown]
# ### 3. What is an object in OOP?
# An object is an instance of a class with its own data and behavior.

# %% [markdown]
# ### 4. What is the difference between abstraction and encapsulation?
# Abstraction hides complexity while encapsulation bundles data and methods and restricts access.

# %% [markdown]
# ### 5. What are dunder methods in Python?
# Dunder methods are special Python methods starting and ending with __.

# %% [markdown]
# ### 6. Explain the concept of inheritance in OOP.
# Inheritance allows a class to acquire properties of another class.

# %% [markdown]
# ### 7. What is polymorphism in OOP?
# Polymorphism means the same method name works differently depending on the object.

# %% [markdown]
# ### 8. How is encapsulation achieved in Python?
# Encapsulation in Python is achieved via private/protected variables.

# %% [markdown]
# ### 9. What is a constructor in Python?
# A constructor init initializes object attributes when an object is created.

# %% [markdown]
# ### 10. What are class and static methods in Python?
# Class methods use @classmethod and access class-level data while static methods use @staticmethod and don't access class or instance.

# %% [markdown]
# ### 11. What is method overloading in Python?
# Method overloading defines multiple methods with the same name but different numbers or types of parameters within a class.

# %% [markdown]
# ### 12. What is method overriding in OOP?
# Method overriding is redefining a parent class method in a child class.

# %% [markdown]
# ### 13. What is a property decorator in Python?
# @property decorator turns a method into an attribute-like getter.

# %% [markdown]
# ### 14. Why is polymorphism important in OOP?
# Polymorphism increases flexibility by allowing different objects to be used interchangeably.

# %% [markdown]
# ### 15. What is an abstract class in Python?
# An abstract class defines methods that must be implemented by subclasses.

# %% [markdown]
# ### 16. What are the advantages of OOP?
# Advantages of OOP: modularity, reusability, scalability, abstraction.

# %% [markdown]
# ### 17. What is the difference between a class variable and an instance variable?
# Class variable is shared across all objects while instance variable is unique to each object.

# %% [markdown]
# ### 18. What is multiple inheritance in Python?
# Multiple inheritance means a class can inherit from more than one parent class.

# %% [markdown]
# ### 19. Explain the purpose of "str" and "repr" methods in Python.
# str returns a human-readable string while repr returns a developer-focused representation.

# %% [markdown]
# ### 20. What is the significance of the "super()" function in Python?
# super() calls methods of the parent class.

# %% [markdown]
# ### 21. What is the significance of the del method in Python?
# del is a destructor called when an object is about to be deleted.

# %% [markdown]
# ### 22. What is the difference between @staticmethod and @classmethod in Python?
# @staticmethod doesn't take self or cls while @classmethod takes cls and works with class data.

# %% [markdown]
# ### 23. How does polymorphism work in Python with inheritance?
# Polymorphism with inheritance works when child classes override parent methods, but are accessed via parent reference.

# %% [markdown]
# ### 24. What is method chaining in Python OOP?
# Method chaining returns self from methods so multiple calls can be made in one line.

# %% [markdown]
# ### 25. What is the purpose of the call method in Python?
# call lets an object be called like a function.

# %%
#1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".
class Animal:
    def speak(self):
        print("Animal makes a sound.")

class Dog(Animal):
    def speak(self):
        print("Bark!")

d = Dog()
d.speak()
# Out:
# Bark!

# %%
#2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height
    def area(self):
        return self.width * self.height

print(Circle(5).area())
print(Rectangle(4, 6).area())
# Out:
# 78.5
# 24

# %%
#3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type):
        super().__init__(type)

class ElectricCar(Car):
    def __init__(self, type, battery):
        super().__init__(type)
        self.battery = battery

e = ElectricCar("Sedan", "80 kWh")
print(e.type, e.battery)
# Out:
# Sedan 80 kWh

# %%
#4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.
class Bird:
    def fly(self):
        print("Bird is flying.")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high.")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly.")

Bird().fly()
Sparrow().fly()
Penguin().fly()
# Out:
# Bird is flying.
# Sparrow flies high.
# Penguin cannot fly.

# %%
#5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance
    def deposit(self, amount):
        self.__balance += amount
    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
    def get_balance(self):
        return self.__balance

acc = BankAccount(100)
acc.deposit(50)
acc.withdraw(30)
print(acc.get_balance())
# Out:
# 120

# %%
#6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().
class Instrument:
    def play(self):
        print("Instrument playing.")

class Guitar(Instrument):
    def play(self):
        print("Guitar sound.")

class Piano(Instrument):
    def play(self):
        print("Piano sound.")

Instrument().play()
Guitar().play()
Piano().play()
# Out:
# Instrument playing.
# Guitar sound.
# Piano sound.

# %%
#7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b
    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print(MathOperations.add_numbers(5, 3))
print(MathOperations.subtract_numbers(10, 4))
# Out:
# 8
# 6

# %%
#8. Implement a class Person with a class method to count the total number of persons created.
class Person:
    count = 0
    def __init__(self):
        Person.count += 1
    @classmethod
    def total_persons(cls):
        return cls.count

p1 = Person()
p2 = Person()
print(Person.total_persons())
# Out:
# 2

# %%
#9. Write a class Fraction with attributes numerator and denominator. Override the __str__ method to display the fraction as "numerator/denominator".
class Fraction:
    def __init__(self, num, den):
        self.num = num
        self.den = den
    def __str__(self):
        return f"{self.num}/{self.den}"

print(Fraction(3, 4))
# Out:
# 3/4

# %%
#10. Demonstrate operator overloading by creating a class Vector and overriding the __add__ method to add two vectors.
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)
    def __repr__(self):
        return f"Vector({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(4, 1)
print(v1 + v2)
# Out:
# Vector(6, 4)

# %%
#11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("Kunal", 22)
p.greet()
# Out:
# Hello, my name is Kunal and I am 22 years old.

# %%
#12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades
    def average_grade(self):
        return sum(self.grades) / len(self.grades)

s = Student("Kunal", [90, 85, 80])
print(s.average_grade())
# Out:
# 85.0

# %%
#13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
class Rectangle:
    def set_dimensions(self, w, h):
        self.w = w
        self.h = h
    def area(self):
        return self.w * self.h

r = Rectangle()
r.set_dimensions(5, 10)
print(r.area())
# Out:
# 50

# %%
#14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:
    def __init__(self, hours, rate):
        self.hours = hours
        self.rate = rate
    def calculate_salary(self):
        return self.hours * self.rate

class Manager(Employee):
    def __init__(self, hours, rate, bonus):
        super().__init__(hours, rate)
        self.bonus = bonus
    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

m = Manager(40, 20, 200)
print(m.calculate_salary())
# Out:
# 1000

# %%
#15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.
class Product:
    def __init__(self, name, price, qty):
        self.name = name
        self.price = price
        self.qty = qty
    def total_price(self):
        return self.price * self.qty

p = Product("Laptop", 50000, 2)
print(p.total_price())
# Out:
# 100000

# %%
#16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo"

class Sheep(Animal):
    def sound(self):
        return "Baa"

print(Cow().sound())
print(Sheep().sound())
# Out:
# Moo
# Baa

# %%
#17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year
    def get_book_info(self):
        return f"{self.title} by {self.author} ({self.year})"

b = Book("Python", "Guido", 1991)
print(b.get_book_info())
# Out:
# Python by Guido (1991)

# %%
#18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, rooms):
        super().__init__(address, price)
        self.rooms = rooms

m = Mansion("Delhi", 50000000, 12)
print(m.address, m.price, m.rooms)
# Out:
# Delhi 50000000 12
