# %% [markdown]
# ###1. What is Simple Linear Regression?
# It models the linear relationship between one independent variable and one dependent variable.

# %% [markdown]
# ###2. What are the key assumptions of Simple Linear Regression?
# Linearity, independence, homoscedasticity, normality of errors, and no autocorrelation.

# %% [markdown]
# ###3. What does the coefficient m represent in the equation Y = mX + c?
# m represents the change in Y for a one-unit change in X.

# %% [markdown]
# ###4. What does the intercept c represent in the equation Y = mX + c?
# c is the expected value of Y when X equals zero.

# %% [markdown]
# ###5. How do we calculate the slope m in Simple Linear Regression?
# m is calculated by minimizing the sum of squared residuals (least squares).

# %% [markdown]
# ###6. What is the purpose of the least squares method in Simple Linear Regression?
# It finds the best-fitting line by minimizing prediction errors.

# %% [markdown]
# ###7. How is the coefficient of determination (R^2) interpreted in Simple Linear Regression?
# R^2 shows the proportion of variance in Y explained by X.

# %% [markdown]
# ###8. What is Multiple Linear Regression?
# It models the relationship between one dependent variable and multiple independent variables.

# %% [markdown]
# ###9. What is the main difference between Simple and Multiple Linear Regression?
# Simple uses one predictor; multiple uses more than one predictor.

# %% [markdown]
# ###10. What are the key assumptions of Multiple Linear Regression?
# Linearity, independence, normality, homoscedasticity, and no multicollinearity.

# %% [markdown]
# ###11. What is heteroscedasticity, and how does it affect the results of a Multiple Linear Regression model?
# It means non-constant error variance, leading to unreliable standard errors.

# %% [markdown]
# ###12. How can you improve a Multiple Linear Regression model with high multicollinearity?
# Remove variables, use regularization, or apply PCA.

# %% [markdown]
# ###13. What are some common techniques for transforming categorical variables for use in regression models?
# One-hot encoding, label encoding, and dummy variables.

# %% [markdown]
# ###14. What is the role of interaction terms in Multiple Linear Regression?
# They capture combined effects of predictors on the target variable.

# %% [markdown]
# ###15. How can the interpretation of intercept differ between Simple and Multiple Linear Regression?
# In multiple regression, the intercept assumes all predictors are zero simultaneously.

# %% [markdown]
# ###16. What is the significance of the slope in regression analysis, and how does it affect predictions?
# It determines the direction and magnitude of predictions.

# %% [markdown]
# ###17. How does the intercept in a regression model provide context for the relationship between variables?
# It sets the baseline level of the dependent variable.

# %% [markdown]
# ###18. What are the limitations of using R^2 as a sole measure of model performance?
# It ignores overfitting and model complexity.

# %% [markdown]
# ###19. How would you interpret a large standard error for a regression coefficient?
# It indicates high uncertainty and low reliability of the coefficient.

# %% [markdown]
# ###20. How can heteroscedasticity be identified in residual plots, and why is it important to address it?
# By funnel-shaped residuals; it affects hypothesis testing accuracy.

# %% [markdown]
# ###21. What does it mean if a Multiple Linear Regression model has a high R^2 but low adjusted R^2?
# Irrelevant predictors are inflating model fit.

# %% [markdown]
# ###22. Why is it important to scale variables in Multiple Linear Regression?
# It ensures fair coefficient comparison and improves numerical stability.

# %% [markdown]
# ###23. What is polynomial regression?
# It models nonlinear relationships using polynomial terms.

# %% [markdown]
# ###24. How does polynomial regression differ from linear regression?
# It includes higher-degree terms of predictors.

# %% [markdown]
# ###25. When is polynomial regression used?
# When data shows a curved relationship.

# %% [markdown]
# ###26. What is the general equation for polynomial regression?
# Y = β0 + β1X + β2X^2 + … + βnX^n.

# %% [markdown]
# ###27. Can polynomial regression be applied to multiple variables?
# Yes, polynomial terms can be added for multiple predictors.

# %% [markdown]
# ###28. What are the limitations of polynomial regression?
# Overfitting, poor extrapolation, and sensitivity to outliers.

# %% [markdown]
# ###29. What methods can be used to evaluate model fit when selecting the degree of a polynomial?
# Cross-validation, adjusted R^2, AIC, and BIC.

# %% [markdown]
# ###30. Why is visualization important in polynomial regression?
# It helps detect underfitting, overfitting, and trend shape.

# %% [markdown]
# ###31. How is polynomial regression implemented in Python?
# By generating polynomial features and fitting a linear model.
