# %% [markdown]
# ###1. What is Boosting in Machine Learning?
# Boosting is an ensemble technique that builds models sequentially, focusing on correcting previous errors.

# %% [markdown]
# ###2. How does Boosting differ from Bagging?
# Boosting reduces bias using sequential learning, while Bagging reduces variance using parallel learning.

# %% [markdown]
# ###3. What is the key idea behind AdaBoost?
# It increases the weight of misclassified samples so later models focus on hard cases.

# %% [markdown]
# ###4. Explain the working of AdaBoost with an example.
# Weak learners are trained iteratively, and misclassified points get higher importance each round.

# %% [markdown]
# ###5. What is Gradient Boosting, and how is it different from AdaBoost?
# Gradient Boosting minimizes a loss function using gradients, while AdaBoost reweights samples.

# %% [markdown]
# ###6. What is the loss function in Gradient Boosting?
# It measures prediction error, such as MSE for regression or log loss for classification.

# %% [markdown]
# ###7. How does XGBoost improve over traditional Gradient Boosting?
# It adds regularization, parallelization, and optimized tree construction.

# %% [markdown]
# ###8. What is the difference between XGBoost and CatBoost?
# XGBoost needs encoded categories; CatBoost handles categorical features natively.

# %% [markdown]
# ###9. What are some real-world applications of Boosting techniques?
# Fraud detection, recommendation systems, ranking, and credit scoring.

# %% [markdown]
# ###10. How does regularization help in XGBoost?
# It prevents overfitting by penalizing complex trees.

# %% [markdown]
# ###11. What are some hyperparameters to tune in Gradient Boosting models?
# Learning rate, number of estimators, max depth, and subsample ratio.

# %% [markdown]
# ###12. What is the concept of Feature Importance in Boosting?
# It measures how much each feature contributes to reducing the loss.

# %% [markdown]
# ###13. Why is CatBoost efficient for categorical data?
# It uses ordered target encoding to avoid data leakage and improve performance.

# %%
#14 - Train an AdaBoost Classifier on a sample dataset and print model accuracy.

from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

model = AdaBoostClassifier(random_state=42)
model.fit(X_train, y_train)

print(accuracy_score(y_test, model.predict(X_test)))
# Out:
# 0.9473684210526315

# %%
#15 - Train an AdaBoost Regressor and evaluate performance using Mean Absolute Error (MAE).

from sklearn.datasets import fetch_california_housing
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_absolute_error

X, y = fetch_california_housing(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

model = AdaBoostRegressor(random_state=42)
model.fit(X_train, y_train)

print(mean_absolute_error(y_test, model.predict(X_test)))
# Out:
# 0.7917933612559462

# %%
#16 - Train a Gradient Boosting Classifier on the Breast Cancer dataset and print feature importance.

from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import GradientBoostingClassifier

X, y = load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

model = GradientBoostingClassifier(random_state=42)
model.fit(X_train, y_train)

print(model.feature_importances_)
# Out:
# [8.89150214e-04 1.79085387e-02 4.93083605e-04 8.84982852e-05
#  1.93410706e-04 2.82049964e-03 2.87739793e-05 4.74560845e-01
#  4.10643086e-04 1.52187815e-04 7.09690716e-03 6.47707429e-03
#  5.82945151e-04 8.86944608e-03 1.35904486e-03 1.93299695e-03
#  1.28898526e-02 9.27634252e-03 1.49420695e-03 1.74321008e-03
#  6.85475586e-02 5.15975109e-02 2.73858239e-02 4.41475366e-02
#  4.09784590e-03 6.68395712e-04 1.65128368e-02 2.36669994e-01
#  1.09221782e-03 1.26227352e-05]

# %%
#17 - Train a Gradient Boosting Regressor and evaluate using R-Squared Score.

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score

model = GradientBoostingRegressor(random_state=42)
model.fit(X_train, y_train)

print(r2_score(y_test, model.predict(X_test)))
# Out:
# 0.86707107288374

# %%
#18 - Train an XGBoost Classifier on a dataset and compare accuracy with Gradient Boosting.

from xgboost import XGBClassifier

xgb = XGBClassifier(use_label_encoder=False, eval_metric="logloss")
gb = GradientBoostingClassifier()

xgb.fit(X_train, y_train)
gb.fit(X_train, y_train)

print(accuracy_score(y_test, xgb.predict(X_test)))
print(accuracy_score(y_test, gb.predict(X_test)))
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:22:14] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 0.965034965034965
# 0.958041958041958

# %%
#19 - Train a CatBoost Classifier and evaluate using F1-Score.

from catboost import CatBoostClassifier
from sklearn.metrics import f1_score

model = CatBoostClassifier(verbose=0)
model.fit(X_train, y_train)

pred = model.predict(X_test)
print(f1_score(y_test, pred, average="macro"))
# Out:
# 0.970020964360587

# %%
#20 - Train an XGBoost Regressor and evaluate using Mean Squared Error (MSE).

from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

model = XGBRegressor()
model.fit(X_train, y_train)

print(mean_squared_error(y_test, model.predict(X_test)))
# Out:
# 0.04561951383948326

# %%
#21 - Train an AdaBoost Classifier and visualize feature importance.

model = AdaBoostClassifier(random_state=42)
model.fit(X_train, y_train)

print(model.feature_importances_)
# Out:
# [0.         0.06021688 0.         0.02924232 0.01849246 0.03389224
#  0.         0.09288805 0.04408613 0.01898409 0.04975911 0.
#  0.01539876 0.01986039 0.         0.05729443 0.         0.0225204
#  0.02063414 0.02539052 0.         0.09766138 0.         0.12564702
#  0.069063   0.         0.04504269 0.09378654 0.06013946 0.        ]

# %%
#22 - Train a Gradient Boosting Regressor and plot learning curves.

import matplotlib.pyplot as plt

model = GradientBoostingRegressor(random_state=42)
model.fit(X_train, y_train)

plt.plot(model.train_score_)
plt.show()

print(len(model.train_score_))
# Out:
# 100

# %%
#23 - Train an XGBoost Classifier and visualize feature importance.

import matplotlib.pyplot as plt

model = XGBClassifier(use_label_encoder=False, eval_metric="logloss")
model.fit(X_train, y_train)

plt.bar(range(len(model.feature_importances_)), model.feature_importances_)
plt.show()

print(model.feature_importances_)
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:22:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [0.         0.01997226 0.         0.00183028 0.00237761 0.00453934
#  0.00130022 0.40246603 0.00426608 0.00189412 0.01684794 0.01478622
#  0.02214287 0.00996099 0.00239191 0.00341116 0.01732392 0.00215872
#  0.00310054 0.0158652  0.07447681 0.02111685 0.05556695 0.02304081
#  0.00773622 0.00276944 0.01745678 0.2486754  0.00252521 0.        ]

# %%
#24 - Train a CatBoost Classifier and plot the confusion matrix.

from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test, pred)
sns.heatmap(cm, annot=True, fmt="d")
plt.show()

print(cm)
# Out:
# [[51  3]
#  [ 1 88]]

# %%
#25 - Train an AdaBoost Classifier with different numbers of estimators and compare accuracy.

for n in [10, 50, 100]:
    model = AdaBoostClassifier(n_estimators=n, random_state=42)
    model.fit(X_train, y_train)
    print(n, accuracy_score(y_test, model.predict(X_test)))
# Out:
# 10 0.972027972027972
# 50 0.958041958041958
# 100 0.9790209790209791

# %%
#26 - Train a Gradient Boosting Classifier and visualize the ROC curve.

from sklearn.metrics import roc_curve, auc

probs = gb.predict_proba(X_test)[:,1]
fpr, tpr, _ = roc_curve(y_test, probs)

plt.plot(fpr, tpr)
plt.show()

print(auc(fpr, tpr))
# Out:
# 0.9945900957136912

# %%
#27 - Train an XGBoost Regressor and tune the learning rate using GridSearchCV.

from sklearn.model_selection import GridSearchCV

params = {"learning_rate":[0.01, 0.1, 0.3]}
grid = GridSearchCV(XGBRegressor(), params)
grid.fit(X_train, y_train)

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'learning_rate': 0.1}
# 0.8128592491149902

# %%
#28 - Train a CatBoost Classifier on an imbalanced dataset and compare performance with class weighting.

from sklearn.datasets import make_classification

X, y = make_classification(weights=[0.9,0.1], random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

model = CatBoostClassifier(class_weights=[1,5], verbose=0)
model.fit(X_train, y_train)

print(accuracy_score(y_test, model.predict(X_test)))
# Out:
# 0.96

# %%
#29 - Train an AdaBoost Classifier and analyze the effect of different learning rates.

for lr in [0.01, 0.1, 1]:
    model = AdaBoostClassifier(learning_rate=lr, random_state=42)
    model.fit(X_train, y_train)
    print(lr, accuracy_score(y_test, model.predict(X_test)))
# Out:
# 0.01 0.92
# 0.1 0.92
# 1 0.92

# %%
#30 - Train an XGBoost Classifier for multi-class classification and evaluate using log-loss.

from sklearn.metrics import log_loss

model = XGBClassifier(use_label_encoder=False, eval_metric="mlogloss")
model.fit(X_train, y_train)

probs = model.predict_proba(X_test)
print(log_loss(y_test, probs))
# Out:
# 0.17133828984216834
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:22:59] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
