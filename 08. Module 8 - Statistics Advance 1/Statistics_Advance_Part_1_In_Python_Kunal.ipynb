# %% [markdown]
# ###1. What is a random variable in probability theory?
# A random variable assigns numerical values to outcomes of a random experiment.

# %% [markdown]
# ###2. What are the types of random variables?
# Discrete and continuous random variables.

# %% [markdown]
# ###3. What is the difference between discrete and continuous distributions?
# Discrete has countable values; continuous has infinite values in a range.

# %% [markdown]
# ###4. What are probability distribution functions (PDF)?
# PDF describes how probability is distributed over values of a random variable.

# %% [markdown]
# ###5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# CDF gives cumulative probability; PDF gives density at a point.

# %% [markdown]
# ###6. What is a discrete uniform distribution?
# All outcomes have equal probability.

# %% [markdown]
# ###7. What are the key properties of a Bernoulli distribution?
# Two outcomes (success/failure) with fixed probability.

# %% [markdown]
# ###8. What is the binomial distribution, and how is it used in probability?
# It models the number of successes in fixed independent trials.

# %% [markdown]
# ###9. What is the Poisson distribution and where is it applied?
# It models rare event counts over a fixed interval.

# %% [markdown]
# ###10. What is a continuous uniform distribution?
# All values in a range have equal probability density.

# %% [markdown]
# ###11. What are the characteristics of a normal distribution?
# It is symmetric, bell-shaped, with mean = median = mode.

# %% [markdown]
# ###12. What is the standard normal distribution, and why is it important?
# It is a normal distribution with mean 0 and standard deviation 1.

# %% [markdown]
# ###13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# CLT states sample means approach normality as sample size increases.

# %% [markdown]
# ###14. How does the Central Limit Theorem relate to the normal distribution?
# It explains why normal distribution appears frequently in real data.

# %% [markdown]
# ###15. What is the application of Z statistics in hypothesis testing?
# Z-statistics test hypotheses using standard normal distribution.

# %% [markdown]
# ###16. How do you calculate a Z-score, and what does it represent?
# Z = (X − μ) / σ; it shows how far a value is from the mean.

# %% [markdown]
# ###17. What are point estimates and interval estimates in statistics?
# Point estimate is a single value; interval estimate gives a range.

# %% [markdown]
# ###18. What is the significance of confidence intervals in statistical analysis?
# They quantify uncertainty around population estimates.

# %% [markdown]
# ###19. What is the relationship between a Z-score and a confidence interval?
# Z-score determines the confidence interval boundaries.

# %% [markdown]
# ###20. How are Z-scores used to compare different distributions?
# They standardize values to a common scale.

# %% [markdown]
# ###21. What are the assumptions for applying the Central Limit Theorem?
# Large sample size and independent, identically distributed samples.

# %% [markdown]
# ###22. What is the concept of expected value in a probability distribution?
# It is the weighted average of all possible outcomes.

# %% [markdown]
# ###23. How does a probability distribution relate to the expected outcome of a random variable?
# The distribution assigns probabilities used to compute expected value.
